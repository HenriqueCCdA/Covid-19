# %% [markdown]
# # <span style='color:green;font-size:200%'> Gráficos de COVID-19 por paises</span>
# ***
#
# ## <span style='color:blue;font-size:100%'> Paises selecionados:</span>
#
# * Brasil

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('casos_e_mortes_confirmados.csv')

# %%
dados_grupo = dados.groupby('Pais')

# %%
dados_grupo.get_group('Brasil').tail(n=5)
# Out:
#            Data   Casos  Mortes    Pais  Dias  Casos_Media_3  Mortes_Media_3  \
# 119  07/05/2020  135773    9190  Brasil    51  125946.333333     8572.000000
# 120  08/05/2020  146894   10017  Brasil    52  136426.000000     9265.000000
# 121  09/05/2020  156061   10656  Brasil    53  146242.666667     9954.333333
# 122  10/05/2020  162699   11123  Brasil    54  155218.000000    10598.666667
# 123  11/05/2020  169594   11653  Brasil    55  162784.666667    11144.000000
#
#      Taxa_Casos_Media_3  Taxa_Mortes_Media_3  Taxa_Casos  Taxa_Mortes  \
# 119        10479.666667           693.000000     11121.0        827.0
# 120         9816.666667           689.333333      9167.0        639.0
# 121         8975.333333           644.333333      6638.0        467.0
# 122         7566.666667           545.333333      6895.0        530.0
# 123                 NaN                  NaN         NaN          NaN
#
#      Porcentagem  Porcentagem_Media_3
# 119         6.77                 6.77
# 120         6.82                 6.82
# 121         6.83                 6.83
# 122         6.84                 6.84
# 123         6.87                 6.87

# %%
# divisao do eixo x
x_ticks = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]

# %% [markdown]
# ----
# ----
# ## <span style='color:green;font-size:150%'> Plotando o gráfico</span>
# ---

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))

name = 'Brasil'
ax1.plot(dados_grupo.get_group(name).Dias, 
             dados_grupo['Casos_Media_3'].get_group(name), 
             label = 'Média movel de 3 dias', 
             color = 'black',
             ls    = '-')

ax1.bar(dados_grupo.get_group(name).Dias, 
        dados_grupo['Casos'].get_group(name),
        label='Acumulado',
        alpha=0.5)

ax1.plot(dados_grupo.get_group(name).Dias, 
             dados_grupo['Taxa_Casos_Media_3'].get_group(name), 
             color = 'black',
             ls    = '-')

ax1.bar(dados_grupo.get_group(name).Dias, 
        dados_grupo['Taxa_Casos'].get_group(name),
        color = 'r',
        label='Novos',
        alpha=0.5)
#

ax2.plot(dados_grupo.get_group(name).Dias, 
             dados_grupo['Mortes_Media_3'].get_group(name), 
             color = 'black',
             ls    = '-')

ax2.bar(dados_grupo.get_group(name).Dias, 
        dados_grupo['Mortes'].get_group(name),
        alpha=0.5)

ax2.plot(dados_grupo.get_group(name).Dias, 
             dados_grupo['Taxa_Mortes_Media_3'].get_group(name), 
             label = 'Média movel de 3 dias', 
             color = 'black',
             ls    = '-')

ax2.bar(dados_grupo.get_group(name).Dias, 
        dados_grupo['Taxa_Mortes'].get_group(name),
        color = 'r',
        alpha=0.5)


# eixo 1
    
# Set the tick labels font
for label in (ax1.get_xticklabels() + ax1.get_yticklabels()):
    label.set_fontsize(16)
#ax1.set_yscale('log')
ax1.set_ylim(0.1, 200000)
ax1.set_xlim(0, 55)
ax1.set_xlabel('Número de dias apartir do 200° caso', fontsize = 16)
ax1.set_ylabel('Número de Casos', fontsize = 16)
ax1.legend(loc = 'upper left', fontsize = 14)
ax1.set_title('Casos Totais Confirmados', fontsize = 28)
ax1.grid(ls = '--')

# eixo 2

# Set the tick labels font
for label in (ax2.get_xticklabels() + ax2.get_yticklabels()):
    label.set_fontsize(16)

#ax2.set_yscale('log') 
ax2.set_ylim(0.1, 20000)
ax2.set_xlim(0, 55)
ax2.set_xlabel('Número de dias apartir do 200° caso', fontsize = 16)
ax2.set_ylabel('Número de Mortes confirmadas', fontsize = 16)
ax2.set_title('Mortes confirmadas', fontsize = 28)
ax2.grid(ls = '--')

plt.show()

# %%
fig.savefig('brasil.png', dpi = 300)

# %% [markdown]
# ---
# ---
