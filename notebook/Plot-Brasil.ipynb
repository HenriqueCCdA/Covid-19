# %% [markdown]
# # <span style='color:green;font-size:200%'> Gráficos de COVID-19 por paises</span>
# ***
#
# ## <span style='color:blue;font-size:100%'> Paises selecionados:</span>
#
# * Brasil

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('casos_e_mortes_confirmados.csv')

# %%
dados_grupo = dados.groupby('Pais')

# %%
dados_grupo.get_group('Brasil').tail(n=5)
# Out:
#            Data    Casos  Mortes    Pais  Dias   Casos_Media  Mortes_Media  \
# 224  29/06/2020  1368195   58314  Brasil   104  1.266233e+06  55773.285714
# 225  30/06/2020  1402041   59594  Brasil   105  1.302824e+06  56766.000000
# 226  01/07/2020  1448753   60632  Brasil   106  1.339984e+06  57737.714286
# 227  02/07/2020  1496858   61884  Brasil   107  1.378376e+06  58725.285714
# 228  03/07/2020  1539081   63174  Brasil   108  1.416105e+06  59755.714286
#
#      Taxa_Casos_Media  Taxa_Mortes_Media  Taxa_Casos  Taxa_Mortes  \
# 224      36590.714286         992.714286     33846.0       1280.0
# 225      37160.285714         971.714286     46712.0       1038.0
# 226      38392.000000         987.571429     48105.0       1252.0
# 227      37729.571429        1030.428571     42223.0       1290.0
# 228               NaN                NaN         NaN          NaN
#
#      Porcentagem  Porcentagem_Media
# 224         4.26               4.26
# 225         4.25               4.25
# 226         4.19               4.19
# 227         4.13               4.13
# 228         4.10               4.10

# %%
# divisao do eixo x
x_ticks = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]

# %% [markdown]
# ----
# ----
# ## <span style='color:green;font-size:150%'> Plotando o gráfico</span>
# ---

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))

name = 'Brasil'
ax1.plot(dados_grupo.get_group(name).Dias, 
             dados_grupo['Casos_Media'].get_group(name), 
             label = 'Média movel de 7 dias', 
             color = 'black',
             ls    = '-')

ax1.bar(dados_grupo.get_group(name).Dias, 
        dados_grupo['Casos'].get_group(name),
        label='Acumulado',
        alpha=0.5)

ax1.plot(dados_grupo.get_group(name).Dias, 
             dados_grupo['Taxa_Casos_Media'].get_group(name), 
             color = 'black',
             ls    = '-')

ax1.bar(dados_grupo.get_group(name).Dias, 
        dados_grupo['Taxa_Casos'].get_group(name),
        color = 'r',
        label='Novos',
        alpha=0.5)
#

ax2.plot(dados_grupo.get_group(name).Dias, 
             dados_grupo['Mortes_Media'].get_group(name), 
             color = 'black',
             ls    = '-')

ax2.bar(dados_grupo.get_group(name).Dias, 
        dados_grupo['Mortes'].get_group(name),
        alpha=0.5)

ax2.plot(dados_grupo.get_group(name).Dias, 
             dados_grupo['Taxa_Mortes_Media'].get_group(name), 
             label = 'Média movel de 7 dias', 
             color = 'black',
             ls    = '-')

ax2.bar(dados_grupo.get_group(name).Dias, 
        dados_grupo['Taxa_Mortes'].get_group(name),
        color = 'r',
        alpha=0.5)


# eixo 1
    
# Set the tick labels font
for label in (ax1.get_xticklabels() + ax1.get_yticklabels()):
    label.set_fontsize(16)
#ax1.set_yscale('log')
ax1.set_ylim(0.1, 2000000)
ax1.set_xlim(0, 120)
ax1.set_xlabel('Número de dias apartir do 200° caso', fontsize = 16)
ax1.set_ylabel('Número de Casos', fontsize = 16)
ax1.legend(loc = 'upper left', fontsize = 14)
ax1.set_title('Casos Totais Confirmados', fontsize = 28)
ax1.grid(ls = '--')

# eixo 2

# Set the tick labels font
for label in (ax2.get_xticklabels() + ax2.get_yticklabels()):
    label.set_fontsize(16)

#ax2.set_yscale('log') 
ax2.set_ylim(0.1,100000)
ax2.set_xlim(0, 120)
ax2.set_xlabel('Número de dias apartir do 200° caso', fontsize = 16)
ax2.set_ylabel('Número de Mortes confirmadas', fontsize = 16)
ax2.set_title('Mortes confirmadas', fontsize = 28)
ax2.grid(ls = '--')

plt.show()

# %%
fig.savefig('brasil.png', dpi = 300)

# %% [markdown]
# ---
# ---
