# %% [markdown]
# # <span style='color:green;font-size:200%'> Gráficos de COVID-19 por paises</span>
# ***
#
# ## <span style='color:blue;font-size:100%'> Paises selecionados:</span>
#
# * Brasil

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('casos_e_mortes_confirmados.csv')

# %%
dados_grupo = dados.groupby('Pais')

# %%
dados_grupo.get_group('Brasil').tail(n=10)
# Out:
#            Data   Casos  Mortes    Pais  Dias  Casos_Media_3  Mortes_Media_3  \
# 100  25/04/2020   59324    4057  Brasil    39   54467.666667     3697.333333
# 101  26/04/2020   63100    4286  Brasil    40   58822.333333     4015.666667
# 102  27/04/2020   67446    4603  Brasil    41   63290.000000     4315.333333
# 103  28/04/2020   73235    5083  Brasil    42   67927.000000     4657.333333
# 104  29/04/2020   79685    5513  Brasil    43   73455.333333     5066.333333
# 105  30/04/2020   87187    6006  Brasil    44   80035.666667     5534.000000
# 106  01/05/2020   92202    6412  Brasil    45   86358.000000     5977.000000
# 107  02/05/2020   97100    6761  Brasil    46   92163.000000     6393.000000
# 108  03/05/2020  101826    7051  Brasil    47   97042.666667     6741.333333
# 109  04/05/2020  108620    7367  Brasil    48  102515.333333     7059.666667
#
#      Taxa_Casos_Media_3  Taxa_Mortes_Media_3  Taxa_Casos  Taxa_Mortes  \
# 100         4354.666667           318.333333      3776.0        229.0
# 101         4467.666667           299.666667      4346.0        317.0
# 102         4637.000000           342.000000      5789.0        480.0
# 103         5528.333333           409.000000      6450.0        430.0
# 104         6580.333333           467.666667      7502.0        493.0
# 105         6322.333333           443.000000      5015.0        406.0
# 106         5805.000000           416.000000      4898.0        349.0
# 107         4879.666667           348.333333      4726.0        290.0
# 108         5472.666667           318.333333      6794.0        316.0
# 109                 NaN                  NaN         NaN          NaN
#
#      Porcentagem  Porcentagem_Media_3
# 100         6.84                 6.84
# 101         6.79                 6.79
# 102         6.82                 6.82
# 103         6.94                 6.94
# 104         6.92                 6.92
# 105         6.89                 6.89
# 106         6.95                 6.95
# 107         6.96                 6.96
# 108         6.92                 6.92
# 109         6.78                 6.78

# %%
# divisao do eixo x
x_ticks = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]

# %% [markdown]
# ----
# ----
# ## <span style='color:green;font-size:150%'> Plotando o gráfico</span>
# ---

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

name = 'Brasil'
ax1.plot(dados_grupo.get_group(name).Dias, 
             dados_grupo['Casos_Media_3'].get_group(name), 
             label = 'Média movel de 3 dias', 
             color = 'black',
             ls    = '-')

ax1.bar(dados_grupo.get_group(name).Dias, 
        dados_grupo['Casos'].get_group(name),
        label='Acumulado',
        alpha=0.5)

ax1.plot(dados_grupo.get_group(name).Dias, 
             dados_grupo['Taxa_Casos_Media_3'].get_group(name), 
             color = 'black',
             ls    = '-')

ax1.bar(dados_grupo.get_group(name).Dias, 
        dados_grupo['Taxa_Casos'].get_group(name),
        color = 'r',
        label='Novos',
        alpha=0.5)
#

ax2.plot(dados_grupo.get_group(name).Dias, 
             dados_grupo['Mortes_Media_3'].get_group(name), 
             color = 'black',
             ls    = '-')

ax2.bar(dados_grupo.get_group(name).Dias, 
        dados_grupo['Mortes'].get_group(name),
        alpha=0.5)

ax2.plot(dados_grupo.get_group(name).Dias, 
             dados_grupo['Taxa_Mortes_Media_3'].get_group(name), 
             label = 'Média movel de 3 dias', 
             color = 'black',
             ls    = '-')

ax2.bar(dados_grupo.get_group(name).Dias, 
        dados_grupo['Taxa_Mortes'].get_group(name),
        color = 'r',
        alpha=0.5)


# eixo 1
    
# Set the tick labels font
for label in (ax1.get_xticklabels() + ax1.get_yticklabels()):
    label.set_fontsize(16)
#ax1.set_yscale('log')
ax1.set_ylim(0.1, 120000)
ax1.set_xlim(0, 50)
ax1.set_xlabel('Número de dias apartir do 200° caso', fontsize = 18)
ax1.set_ylabel('Número de Casos', fontsize = 18)
ax1.legend(loc = 'upper left', fontsize = 14)
ax1.set_title('Casos Totais Confirmados', fontsize = 28)
ax1.grid(ls = '--')

# eixo 2

# Set the tick labels font
for label in (ax2.get_xticklabels() + ax2.get_yticklabels()):
    label.set_fontsize(16)

#ax2.set_yscale('log') 
ax2.set_xlim(0, 50)
ax2.set_xlabel('Número de dias apartir do 200° caso', fontsize = 18)
ax2.set_ylabel('Número de Mortes confirmadas', fontsize = 18)
ax2.set_title('Mortes confirmadas', fontsize = 28)
ax2.grid(ls = '--')

plt.show()

# %%
fig.savefig('brasil.png', dpi = 200)

# %% [markdown]
# ---
# ---
