# %% [markdown]
# # <span style='color:green;font-size:200%'> Gráficos de COVID-19 por paises</span>
# ***
#
# ## <span style='color:blue;font-size:100%'> Paises selecionados:</span>
# * Africa do Sul
# * Coreia do Sul

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('casos_e_mortes_confirmados.csv')

# %%
dados_grupo = dados.groupby('Pais')

# %%
dados_grupo.get_group('África do Sul').tail()
# Out:
#            Data   Casos  Mortes           Pais  Dias    Casos_Media  \
# 867  07/07/2020  215855    3502  África do Sul   109  187260.142857
# 868  08/07/2020  224665    3602  África do Sul   110  196593.285714
# 869  09/07/2020  238339    3720  África do Sul   111  206633.000000
# 870  10/07/2020  250687    3860  África do Sul   112  217142.000000
# 871  11/07/2020  264184    3971  África do Sul   113  228028.714286
#
#      Mortes_Media  Taxa_Casos_Media  Taxa_Mortes_Media  Taxa_Casos  \
# 867   3083.142857       9333.142857         121.857143      8810.0
# 868   3205.000000      10039.714286         125.142857     13674.0
# 869   3330.142857      10509.000000         129.714286     12348.0
# 870   3459.857143      10886.714286         135.000000     13497.0
# 871   3594.857143               NaN                NaN         NaN
#
#      Taxa_Mortes  Porcentagem  Porcentagem_Media
# 867        100.0         1.62               1.62
# 868        118.0         1.60               1.60
# ...

# %%
paises = ['África do Sul', 'Coreia do Sul']

# %% [markdown]
# ____
# ____
# ## <span style='color:green;font-size:150%'> Plotando o gráfico dos casos totais confirmados</span>
# ____

# %%
x_ticks = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
m       = ['o', 'v', '^', 'x', 's', '>']

fig, ax = plt.subplots(figsize=(12, 6))

for i, name in enumerate(paises):
    ax.semilogy(dados_grupo.get_group(name).Dias, 
                dados_grupo['Casos_Media'].get_group(name), 
                label = name, 
                marker = m[i], 
                markevery = 4)

# Set the tick labels font
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(16)

ax.set_xlim(0, 130)
ax.set_xlabel('Número de dias apartir do 200° caso', fontsize = 18)
ax.set_ylabel('Número de Casos (log)', fontsize = 18)
ax.legend(loc = 'lower right', fontsize = 20)
ax.set_title('Casos', fontsize = 28)
ax.grid(ls = '--')
ax.axvline(x=4.5,ls='--',color='red')
#ax.text(1,1200, 'Início do isolamento na\nAfrica do Sul', fontsize=12, rotation=90, color = 'red')
#ax.text(1,1200, '24/03 : 00:00 h', fontsize=12, rotation=0, color = 'red')
ax

# %%
fig.savefig('Africa_do_sul.png', dpi = 300)

# %%
x_ticks = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
m       = ['o', 'v', '^', 'x', 's', '>']

fig, ax = plt.subplots(figsize=(12, 6))

for i, name in enumerate(paises):
    ax.plot(dados_grupo.get_group(name).Dias,
            dados_grupo['Casos_Media'].get_group(name), 
            label = name, 
            marker = m[i],
            markevery = 4)

# Set the tick labels font
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(16)

ax.set_xlim(0, 150)
ax.set_xlabel('Número de dias apartir do 200° caso', fontsize = 18)
ax.set_ylabel('Número de Casos', fontsize = 18)
ax.legend(loc = 'upper left', fontsize = 20)
ax.set_title('Casos', fontsize = 28)
ax.grid(ls = '--')
ax.axvline(x=4.5,ls='--',color='red')
#ax.text(2,3000, 'Início do isolamento na\nAfrica do Sul', fontsize=12, rotation=90, color = 'red')
#ax.text(1,-1000, '24/03 : 00:00 h', fontsize=12, rotation=0, color = 'red')
ax

# %% [markdown]
# ---
# ---

# %% [markdown]
# ____
# ____
# ## <span style='color:green;font-size:150%'> Plotando o gráfico de mortes totais confirmados</span>
# ____

# %%
x_ticks = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
m       = ['o', 'v', '^', 'x', 's', '>']

fig, ax = plt.subplots(figsize=(12, 6))

for i, name in enumerate(paises):
    ax.semilogy(dados_grupo.get_group(name).Dias, 
                dados_grupo['Mortes_Media'].get_group(name), 
                label = name,
                marker = m[i],
                markevery = 4)

# Set the tick labels font
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(16)

ax.set_xlim(0, 150)
ax.set_xlabel('Número de dias apartir do 200° caso', fontsize = 18)
ax.set_ylabel('Número de Mortes (log)', fontsize = 18)
ax.legend(loc = 'lower right', fontsize = 20)
ax.set_title('Mortes', fontsize = 28)
ax.grid(ls = '--')
ax.axvline(x=4.5,ls='--',color='red')
#ax.text(2,15, 'Início do isolamento na\nAfrica do Sul', fontsize=12, rotation=90, color = 'red')
#ax.text(1,0.15, '24/03 : 00:00 h', fontsize=12, rotation=0, color = 'red')
ax

# %%
x_ticks = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
m       = ['o', 'v', '^', 'x', 's', '>']

fig, ax = plt.subplots(figsize=(12, 6))

for i, name in enumerate(paises):
    ax.plot(dados_grupo.get_group(name).Dias,
            dados_grupo['Mortes_Media'].get_group(name), 
            label = name, 
            marker = m[i],
            markevery = 4)

# Set the tick labels font
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(16)

ax.set_xlim(0, 150)
ax.set_xlabel('Número de dias apartir do 200° caso', fontsize = 18)
ax.set_ylabel('Número de Mortes', fontsize = 18)
ax.legend(loc = 'upper left', fontsize = 20)
ax.set_title('Mortes', fontsize = 28)
ax.grid(ls = '--')
ax.axvline(x=4.5,ls='--',color='red')
#ax.text(2,3000, 'Início do isolamento na\nAfrica do Sul', fontsize=12, rotation=90, color = 'red')
#ax.text(1,-1000, '24/03 : 00:00 h', fontsize=12, rotation=0, color = 'red')
ax
