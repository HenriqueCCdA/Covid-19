# %% [markdown]
# # <span style='color:green;font-size:200%'> Gráficos de COVID-19 por paises</span>
# ***
#
# ## <span style='color:blue;font-size:100%'> Paises selecionados:</span>
# * Africa do Sul
# * Coreia do Sul

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('casos_e_mortes_confirmados.csv')

# %%
dados_grupo = dados.groupby('Pais')

# %%
dados_grupo.get_group('África do Sul').tail()
# Out:
#            Data  Casos  Mortes           Pais  Dias  Casos_Media_3  \
# 385  29/04/2020   5350     103  África do Sul    40    5046.333333
# 386  30/04/2020   5647     103  África do Sul    41    5331.000000
# 387  01/05/2020   5951     116  África do Sul    42    5649.333333
# 388  02/05/2020   6336     123  África do Sul    43    5978.000000
# 389  03/05/2020   6783     131  África do Sul    44    6356.666667
#
#      Mortes_Media_3  Taxa_Casos_Media_3  Taxa_Mortes_Media_3  Porcentagem  \
# 385       95.333333          284.666667             4.333333         1.93
# 386       99.666667          318.333333             7.666667         1.82
# 387      107.333333          328.666667             6.666667         1.95
# 388      114.000000          378.666667             9.333333         1.94
# 389      123.333333                 NaN                  NaN         1.93
#
#      Porcentagem_Media_3
# 385                 1.93
# 386                 1.82
# 387                 1.95
# 388                 1.94
# 389                 1.93

# %%
paises = ['África do Sul', 'Coreia do Sul']

# %% [markdown]
# ____
# ____
# ## <span style='color:green;font-size:150%'> Plotando o gráfico dos casos totais confirmados</span>
# ____

# %%
x_ticks = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
m       = ['o', 'v', '^', 'x', 's', '>']

fig, ax = plt.subplots(figsize=(12, 6))

for i, name in enumerate(paises):
    ax.semilogy(dados_grupo.get_group(name).Dias, dados_grupo['Casos_Media_3'].get_group(name), label = name, marker = m[i])

# Set the tick labels font
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(16)

ax.set_xlim(0, 55)
ax.set_xlabel('Número de dias apartir do 200° caso', fontsize = 18)
ax.set_ylabel('Número de Casos (log)', fontsize = 18)
ax.legend(loc = 'lower right', fontsize = 20)
ax.set_title('Casos', fontsize = 28)
ax.grid(ls = '--')
ax.axvline(x=4.5,ls='--',color='red')
ax.text(2,1200, 'Início do isolamento na\nAfrica do Sul', fontsize=12, rotation=90, color = 'red')
ax.text(2,95, '24/03 : 00:00 h', fontsize=12, rotation=0, color = 'red')
ax

# %%
fig.savefig('Africa_do_sul.png', dpi = 200)

# %%
x_ticks = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
m       = ['o', 'v', '^', 'x', 's', '>']

fig, ax = plt.subplots(figsize=(12, 6))

for i, name in enumerate(paises):
    ax.plot(dados_grupo.get_group(name).Dias,
            dados_grupo['Casos_Media_3'].get_group(name), 
            label = name, 
            marker = m[i])

# Set the tick labels font
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(16)

ax.set_xlim(0, 55)
ax.set_xlabel('Número de dias apartir do 200° caso', fontsize = 18)
ax.set_ylabel('Número de Casos', fontsize = 18)
ax.legend(loc = 'lower right', fontsize = 20)
ax.set_title('Casos', fontsize = 28)
ax.grid(ls = '--')
ax.axvline(x=4.5,ls='--',color='red')
ax.text(2,3000, 'Início do isolamento na\nAfrica do Sul', fontsize=12, rotation=90, color = 'red')
ax.text(1,-1000, '24/03 : 00:00 h', fontsize=12, rotation=0, color = 'red')
ax

# %% [markdown]
# ---
# ---

# %% [markdown]
# ____
# ____
# ## <span style='color:green;font-size:150%'> Plotando o gráfico de mortes totais confirmados</span>
# ____

# %%
x_ticks = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
m       = ['o', 'v', '^', 'x', 's', '>']

fig, ax = plt.subplots(figsize=(12, 6))

for i, name in enumerate(paises):
    ax.semilogy(dados_grupo.get_group(name).Dias, 
                dados_grupo['Mortes_Media_3'].get_group(name), 
                label = name, marker = m[i])

# Set the tick labels font
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(16)

ax.set_xlim(0, 55)
ax.set_xlabel('Número de dias apartir do 200° caso', fontsize = 18)
ax.set_ylabel('Número de Mortes (log)', fontsize = 18)
ax.legend(loc = 'lower right', fontsize = 20)
ax.set_title('Mortes', fontsize = 28)
ax.grid(ls = '--')
ax.axvline(x=4.5,ls='--',color='red')
ax.text(2,15, 'Início do isolamento na\nAfrica do Sul', fontsize=12, rotation=90, color = 'red')
ax.text(1,0.15, '24/03 : 00:00 h', fontsize=12, rotation=0, color = 'red')
ax

# %%
x_ticks = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
m       = ['o', 'v', '^', 'x', 's', '>']

fig, ax = plt.subplots(figsize=(12, 6))

for i, name in enumerate(paises):
    ax.plot(dados_grupo.get_group(name).Dias,
            dados_grupo['Mortes_Media_3'].get_group(name), 
            label = name, 
            marker = m[i])

# Set the tick labels font
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(16)

ax.set_xlim(0, 55)
ax.set_xlabel('Número de dias apartir do 200° caso', fontsize = 18)
ax.set_ylabel('Número de Mortes', fontsize = 18)
ax.legend(loc = 'lower right', fontsize = 20)
ax.set_title('Mortes', fontsize = 28)
ax.grid(ls = '--')
ax.axvline(x=4.5,ls='--',color='red')
#ax.text(2,3000, 'Início do isolamento na\nAfrica do Sul', fontsize=12, rotation=90, color = 'red')
#ax.text(1,-1000, '24/03 : 00:00 h', fontsize=12, rotation=0, color = 'red')
ax
